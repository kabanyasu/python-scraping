# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import json
import datetime
import random
import re

random.seed(datetime.datetime.now())
def getLinks(articleUrl):
    html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).findAll('a', 
        href=re.compile('^(/wiki/)((?!:).)*$'))

def getHistoryIPs(pageUrl):
    #Format of revision history pages is: 
    #http://en.wikipedia.org/w/index.php?title=Title_in_URL&action=history
    pageUrl = pageUrl.replace('/wiki/', '')
    historyUrl = 'http://en.wikipedia.org/w/index.php?title={}&action=history'.format(pageUrl)
    print('history url is: {}'.format(historyUrl))
    html = urlopen(historyUrl)
    bs = BeautifulSoup(html, 'html.parser')
    #finds only the links with class "mw-anonuserlink" which has IP addresses 
    #instead of usernames
    ipAddresses = bs.findAll('a', {'class':'mw-anonuserlink'})
    addressList = set()
    for ipAddress in ipAddresses:
        addressList.add(ipAddress.get_text())
    return addressList

links = getLinks('/wiki/Python_(programming_language)')

while(len(links) > 0):
    for link in links:
        print('-'*20) 
        historyIPs = getHistoryIPs(link.attrs['href'])
        for historyIP in historyIPs:
            print(historyIP)

    newLink = links[random.randint(0, len(links)-1)].attrs['href']
    links = getLinks(newLink)
# Out:
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Programming_paradigm&action=history
# 129.7.106.20
# 2a02:c7d:a492:f200:e126:2b36:53ca:513a
# 174.254.128.149
# 68.151.180.83
# 49.197.5.59
# 66.87.149.174
# 31.223.170.65
# 2605:6000:ec0f:c800:edfd:179f:b648:b4b9
# 213.133.47.254
# 192.159.69.162
# 2405:204:6694:d402::2964:90a1
# 218.17.157.55
# 2601:14b:4301:19c3:9107:8bad:dbf7:5803
# 117.221.183.123
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Multi-paradigm_programming_language&action=history
# 75.139.254.117
# 98.197.198.46
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Functional_programming&action=history
# 129.7.106.20
# 194.55.194.254
# 212.112.100.239
# 174.116.65.139
# 49.197.5.59
# 205.175.119.118
# 2405:205:24a7:f8d4:4a2c:f2a7:55e5:7d7d
# 140.177.205.223
# 144.51.242.26
# 90.95.200.195
# 193.57.249.5
# 210.212.209.66
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Imperative_programming&action=history
# 178.208.206.244
# 15.203.233.84
# 111.92.130.14
# 94.118.222.35
# 197.239.7.126
# 176.60.44.112
# 188.146.23.38
# 204.84.232.231
# 152.231.35.89
# 2600:1004:b151:6515:1c2a:675b:bb28:2986
# 85.133.27.110
# 83.244.156.56
# 194.181.240.192
# 5.199.208.23
# 107.107.62.0
# 114.79.32.242
# 117.136.79.80
# 140.177.205.223
# 180.191.95.166
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Object-oriented_programming&action=history
# 210.230.167.44
# 2a01:6500:a102:930b:50e1:a0:40e9:c9e7
# 144.138.25.66
# 2001:1970:5e63:e700:cb9:6b91:8e39:e3fc
# 2401:4900:110a:fe22:6c6a:dfb6:3848:df72
# 47.8.237.71
# 24.119.150.98
# 123.136.112.57
# 103.5.135.10
# 14.139.239.74
# 139.167.226.163
# 213.175.187.82
# 50.234.174.10
# 86.94.215.205
# 125.18.177.101
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Reflective_programming&action=history
# 212.96.25.37
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Software_design&action=history
# 116.75.208.148
# 2405:204:6680:3546::3c2:60b0
# 73.83.224.42
# 183.82.123.14
# 37.228.230.26
# 91.180.76.245
# 24.18.107.108
# 41.59.251.118
# 39.45.197.130
# 97.107.121.1
# 49.248.91.74
# 217.114.169.247
# 98.26.67.24
# 63.98.63.242
# 37.191.210.104
# 217.114.161.18
# 183.83.156.114
# 102.181.54.242
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Dialect_(computing)&action=history
# 76.71.235.164
# 203.177.247.192
# 89.163.66.103
# 67.142.130.40
# 78.32.219.25
# 99.63.60.16
# 24.235.188.174
# 189.82.188.108
# 200.126.223.126
# 71.12.189.127
# 172.206.111.187
# 66.74.176.59
# 124.124.52.164
# 213.207.90.158
# 118.210.197.145
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Cython&action=history
# 185.193.199.213
# 2600:6c58:627f:e8ca:81c8:2af8:becd:f3d4
# 79.13.132.173
# 70.36.145.190
# 148.88.152.95
# 88.111.109.115
# 84.224.142.98
# 70.184.214.35
# 179.50.208.75
# 212.216.239.205
# 173.230.196.25
# 160.3.49.37
# 173.228.46.185
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=RPython&action=history
# 85.178.124.81
# 85.178.179.11
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=ABC_(programming_language)&action=history
# 67.183.15.243
# 24.218.155.160
# 117.195.212.149
# 72.188.68.228
# 113.162.145.67
# 24.106.95.243
# 24.91.6.95
# 14.1.193.137
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=ALGOL_68&action=history
# 86.155.125.253
# 63.230.188.98
# 106.70.223.61
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=APL_(programming_language)&action=history
# 2001:8b0:181:1:2561:44a4:93d2:82a0
# 104.35.94.229
# 218.5.241.6
# 2001:8b0:181:1:e030:2744:e319:22be
# 209.6.209.51
# 88.114.9.150
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=C_(programming_language)&action=history
# 2607:fea8:21e0:d7a:6cbc:d5b5:789c:2e0d
# 106.211.73.33
# 2402:3a80:9a4:9909:1993:52ba:3b79:fead
# 2405:204:c203:b9e9:be3c:466a:40f3:cddc
# 2402:3a80:ddb:a2d2:8003:37ec:bdf0:9e9e
# 42.111.204.117
# 2405:204:148c:4fc3::10d4:a8a4
# 24.204.32.226
# 108.20.28.239
# 2600:1010:b01b:c4e:a9e1:857d:d1f4:dd1a
# 61.12.45.214
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=C%2B%2B&action=history
# 74.101.43.105
# 2601:703:200:8f7:1450:a644:f4e5:c5dd
# 2601:703:200:8f7:fc9d:aaee:d0fe:2ec3
# 81.6.34.246
# 67.209.188.66
# 114.29.237.80
# 2601:647:cb02:5034:a9d9:c859:43b3:99d4
# 2405:205:3091:3309:edab:2ff6:43a:96de
# 182.65.32.11
# 74.215.253.211
# 76.102.7.183
# 120.56.247.144
# 98.110.246.161
# 82.137.14.50
# 42.111.13.99
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=CLU_(programming_language)&action=history
# 50.53.15.108
# 121.45.201.112
# 143.85.199.242
# 171.61.182.6
# 204.19.162.34
# 124.168.74.249
# 50.53.15.59
# 74.67.220.206
# 86.103.20.202
# 24.166.117.132
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Dylan_(programming_language)&action=history
# 2001:14bb:140:2896:2d4e:154c:5901:946f
# 175.139.31.7
# 112.65.62.144
# 216.38.129.126
# 195.225.189.80
# 64.58.145.95
# 70.231.229.51
# 162.244.179.107
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Haskell_(programming_language)&action=history
# 75.172.200.54
# 2a00:79e0:15:14:8d71:619c:64f4:3e0e
# 121.218.241.43
# 129.170.30.229
# 2600:1015:b066:3c0f:2d02:7f67:7544:58be
# 2a0c:5bc0:40:2b01:add0:96f7:7649:521d
# 2405:204:c101:6240::812:d0b0
# 192.86.3.5
# 2600:1015:b012:8575:6456:4473:db9:fe49
# 2600:1015:b002:a523:3c53:26a8:5f86:2b5
# 209.194.92.138
# 82.159.74.199
# 2600:1015:b00d:d701:8cdd:b051:e6cc:208d
# 209.171.14.170
# 144.208.212.194
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=D_(programming_language)&action=history
# 183.17.125.182
# 2600:1700:fa20:eb0:782c:9d13:b8d7:643a
# 92.37.197.192
# 49.147.20.122
# 113.210.113.160
# 68.57.254.129
# 68.61.215.70
# 31.16.14.227
# 2409:4085:1096:2b7c:734e:9cc6:d7f8:da83
# 24.143.110.148
# 86.184.246.49
# 147.156.121.128
# 81.88.11.187
# 2600:1005:b05a:9c2e:9d17:7d36:776:33ae
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=F_Sharp_(programming_language)&action=history
# 113.20.100.58
# 158.26.2.168
# 158.174.11.253
# 181.113.153.212
# 66.150.189.1
# 175.176.187.34
# 99.226.237.229
# 2601:586:8100:c3bc:dd1e:b6b3:7b21:87a7
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Genie_(programming_language)&action=history
# 2003:cc:fbc5:af00:b567:abe7:e020:eb0
# 137.48.251.106
# 86.31.186.178
# 92.232.218.151
# 83.254.138.122
# 84.250.17.211
# 2003:45:4b41:8b73:cc47:b2bd:c580:f562
# 98.175.61.198
# 217.226.248.110
# 117.212.178.46
# 86.31.184.190
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Go_(programming_language)&action=history
# 120.29.105.95
# 122.174.61.211
# 94.21.238.64
# 2a02:a314:853d:d680:65c6:daa9:4e9d:7a44
# 2620:0:100e:913:e541:9eca:1b74:173e
# 2405:205:87:5a98:bcc4:77ba:b8b0:2811
# 2600:1015:b008:a736:d5b4:4ac6:67ff:7e0b
# 92.23.238.244
# 219.91.139.113
# 2600:1015:b002:a523:3c53:26a8:5f86:2b5
# 2600:1015:b01b:2c95:a015:30ca:f3c:4c49
# 2600:1015:b023:55a7:b8e7:ebd5:d58f:7692
# 37.169.237.242
# 1.32.48.169
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=JavaScript&action=history
# 205.159.101.138
# 47.145.241.158
# 174.27.25.58
# 114.4.79.6
# 207.23.205.127
# 174.76.24.2
# 213.193.97.4
# 98.163.58.237
# 134.134.139.75
# 27.57.170.60
# 74.207.43.24
# 123.252.222.94
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Julia_(programming_language)&action=history
# 72.16.99.93
# 64.119.130.146
# 2600:1702:3ad0:f9c0:2894:a951:b154:6c19
# 220.244.14.217
# 73.67.140.135
# 60.243.84.102
# 128.2.131.9
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Nim_(programming_language)&action=history
# 190.80.244.146
# 190.80.244.132
# 190.167.253.131
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Ring_(programming_language)&action=history
# 94.65.216.254
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Ruby_(programming_language)&action=history
# 62.1.22.95
# 174.224.11.95
# 171.243.159.89
# 50.255.11.217
# 84.78.21.250
# 186.50.213.136
# 41.97.193.9
# 79.113.219.162
# 109.15.218.42
# 69.113.99.90
# 106.207.156.237
# 58.27.159.18
# 86.120.94.220
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Swift_(programming_language)&action=history
# 202.88.246.219
# 130.132.173.162
# 84.60.39.3
# 185.213.154.164
# 87.251.211.11
# 84.15.190.85
# 107.77.214.184
# 76.102.149.8
# 2.51.138.16
# 208.54.86.143
# 182.185.203.149
# 185.213.154.165
# 72.46.206.219
# 2001:569:79cb:400:1076:f97f:c568:db55
# 185.213.154.162
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Interpreted_language&action=history
# 68.34.54.135
# 2600:1700:77a0:24d0:d16f:65e0:d540:b211
# 109.190.217.98
# 174.255.204.228
# 31.223.0.215
# 93.254.17.189
# 217.22.96.73
# 2601:180:8200:1d00:38f1:6975:ae4d:dad8
# 106.51.240.126
# 180.150.12.96
# 121.52.155.242
# 2405:204:f11c:e6b1::1186:b0b1
# 99.104.20.192
# 217.138.22.50
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=High-level_programming_language&action=history
# 27.34.20.24
# 2607:fea8:a4a0:ba:598:9b84:99f0:d40e
# 169.239.26.18
# 106.79.97.60
# 2a02:c7f:1054:700:95a6:fb2a:3e91:8b64
# 189.206.221.42
# 212.219.94.60
# 68.238.250.197
# 117.234.246.195
# 2405:205:2394:629f:c1e2:4325:59b5:ee5a
# 197.237.118.189
# 185.91.128.243
# 43.245.207.89
# 83.110.146.108
# 94.97.253.35
# 2a02:c7d:5ded:3000:20a4:a5:e4a8:538d
# 203.202.247.130
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=General-purpose_programming_language&action=history
# 2402:4000:bbfc:bd0b:b4e2:6f45:fea3:2b3e
# 2604:6000:130a:22a:753f:c2d9:1ceb:66f3
# 5.35.187.69
# 84.211.83.254
# 201.27.236.81
# 173.167.116.225
# 130.226.41.7
# 2607:fea8:91e0:b29:88ed:1e6f:281e:6c17
# 175.157.248.58
# 106.51.66.45
# 156.157.156.8
# 178.164.139.37
# 202.164.30.65
# 60.221.140.44
# 213.103.204.226
# 2a02:810a:1340:7768:58bc:239:3df6:c30b
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Guido_van_Rossum&action=history
# 39.48.109.135
# 81.250.149.84
# 117.201.255.94
# 2409:4072:912:4410::1d90:70ad
# 203.59.222.117
# 75.97.150.244
# 90.145.111.164
# 203.59.244.200
# 2402:3a80:1250:507a:ab59:61bf:7de3:6931
# 196.112.7.25
# 148.253.183.155
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Code_readability&action=history
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Significant_whitespace&action=history
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Dynamic_type&action=history
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Memory_management&action=history
# 192.153.117.2
# 2409:4064:799:4333::26b8:60a1
# 81.134.55.93
# 212.79.110.126
# 2.28.242.213
# 95.218.251.224
# 2405:204:7308:40ca:275d:b604:8af7:d9e6
# 5.41.140.65
# 80.3.214.237
# 180.151.74.34
# 196.43.183.170
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Programming_paradigm&action=history
# 129.7.106.20
# 2a02:c7d:a492:f200:e126:2b36:53ca:513a
# 174.254.128.149
# 68.151.180.83
# 49.197.5.59
# 66.87.149.174
# 31.223.170.65
# 2605:6000:ec0f:c800:edfd:179f:b648:b4b9
# 213.133.47.254
# 192.159.69.162
# 2405:204:6694:d402::2964:90a1
# 218.17.157.55
# 2601:14b:4301:19c3:9107:8bad:dbf7:5803
# 117.221.183.123
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Object-oriented_programming&action=history
# 210.230.167.44
# 2a01:6500:a102:930b:50e1:a0:40e9:c9e7
# 144.138.25.66
# 2001:1970:5e63:e700:cb9:6b91:8e39:e3fc
# 2401:4900:110a:fe22:6c6a:dfb6:3848:df72
# 47.8.237.71
# 24.119.150.98
# 123.136.112.57
# 103.5.135.10
# 14.139.239.74
# 139.167.226.163
# 213.175.187.82
# 50.234.174.10
# 86.94.215.205
# 125.18.177.101
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Guido_van_Rossum&action=history
# 39.48.109.135
# 81.250.149.84
# 117.201.255.94
# 2409:4072:912:4410::1d90:70ad
# 203.59.222.117
# 75.97.150.244
# 90.145.111.164
# 203.59.244.200
# 2402:3a80:1250:507a:ab59:61bf:7de3:6931
# 196.112.7.25
# 148.253.183.155
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Centrum_Wiskunde_%26_Informatica&action=history
# 80.90.171.235
# 2003:dc:7bcf:b100:55c1:2266:5db2:a9e0
# 194.61.223.53
# 217.120.38.253
# 50.53.1.33
# 87.65.171.6
# 163.47.14.201
# 14.161.3.158
# 194.171.31.246
# 77.56.53.183
# 77.172.147.42
# 131.180.220.124
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Netherlands&action=history
# 2a01:111f:e1a:a400:3d73:3832:8ef4:6a39
# 2001:982:22c0:1:f48b:948f:f245:da87
# 145.131.242.9
# 83.84.0.202
# 2.31.106.47
# 2a01:111f:e1a:a400:e085:51bc:a944:db4f
# 185.106.154.190
# 96.79.177.113
# 2a01:111f:e1a:a400:1d3d:9d42:53d0:9114
# 31.217.246.232
# 173.81.152.197
# 2003:c4:3716:1d94:e9df:db89:385c:463d
# 2600:6c50:7f:e2d7:fd10:517d:2f91:3d83
# 82.28.107.46
# 45.216.77.160
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=ABC_(programming_language)&action=history
# 67.183.15.243
# 24.218.155.160
# 117.195.212.149
# 72.188.68.228
# 113.162.145.67
# 24.106.95.243
# 24.91.6.95
# 14.1.193.137
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=SETL&action=history
# 141.31.111.1
# 2607:fea8:a69f:f99a:585c:42ab:70be:dbf
# 24.127.201.40
# 50.53.15.51
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Exception_handling&action=history
# 24.156.169.85
# 31.169.58.161
# 91.103.79.60
# 197.42.132.255
# 91.90.44.27
# 96.250.126.152
# 71.236.213.113
# 65.94.42.219
# 103.233.116.146
# 115.117.133.91
# 103.207.170.205
# 2405:205:c904:62df:9fc:5e0f:f77a:ad43
# 2003:a:e4d:bb01:8078:6cf9:ec8c:c3ad
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Amoeba_(operating_system)&action=history
# 27.97.20.129
# 2601:644:402:7750:2557:500b:9088:58a0
# 87.242.131.50
# 14.169.15.67
# 27.33.140.165
# 223.255.247.194
# 217.128.37.173
# 86.127.135.155
# 93.88.189.236
# 31.50.197.208
# 14.169.56.195
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Benevolent_Dictator_For_Life&action=history
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Cycle_detection&action=history
# 130.58.164.208
# 103.1.57.224
# 76.81.249.42
# 96.237.52.147
# 69.143.175.242
# 103.7.28.136
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Garbage_collection_(computer_science)&action=history
# 159.53.110.142
# 49.151.43.217
# 140.193.242.213
# 2600:1700:cce0:b190:fd80:fa4:2f90:32a8
# 78.96.45.130
# 103.82.99.99
# 87.214.71.4
# 107.77.208.137
# 45.114.134.197
# 103.240.34.250
# 2601:647:4801:b351:5817:b9b4:f7cb:73c
# 202.89.160.187
# 2a00:23c5:6403:c800:2508:2939:a0f1:bffd
# 182.74.243.42
# 110.142.194.98
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Unicode&action=history
# 2600:1700:4231:8130:d832:aafb:f03b:5ba1
# 109.170.158.52
# 2a02:c7d:2894:db00:61f9:3cf6:e2ef:dc03
# 2604:6000:120b:c289:f8a6:3a56:37d0:aba8
# 66.87.124.184
# 175.143.12.20
# 153.180.167.250
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Backward_compatibility&action=history
# 98.215.193.216
# 149.62.200.74
# 2a02:cb80:4044:9e72:60c8:2b75:db1b:5db2
# 73.235.68.134
# 220.247.243.31
# 103.52.140.65
# 2605:a601:41ec:3800:48b5:e909:fa03:19aa
# 5.72.55.82
# 148.75.193.254
# 119.160.118.146
# 204.63.44.146
# 97.33.72.51
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Backporting&action=history
# 186.252.69.209
# 71.72.235.91
# 197.226.33.67
# 76.28.130.42
# 121.54.46.38
# 80.221.11.245
# 205.172.122.150
# 59.162.74.111
# 124.149.93.92
# 98.69.231.42
# 74.242.244.110
# 2600:1003:b100:704d:e15d:4d42:8404:2351
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=End-of-life_(product)&action=history
# 2601:8:b180:26a:9dc1:4162:68ca:2115
# 1.39.62.158
# 173.78.65.214
# 203.125.232.138
# 89.204.155.124
# 2605:6000:6e40:6100:3d6a:62d3:4659:6f6b
# 152.71.146.188
# 80.1.219.140
# 207.96.241.58
# 178.3.164.113
# 89.132.226.116
# 203.196.190.45
# 46.2.40.123
# 223.30.33.228
# 128.170.224.12
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Go_(programming_language)&action=history
# 120.29.105.95
# 122.174.61.211
# 94.21.238.64
# 2a02:a314:853d:d680:65c6:daa9:4e9d:7a44
# 2620:0:100e:913:e541:9eca:1b74:173e
# 2405:205:87:5a98:bcc4:77ba:b8b0:2811
# 2600:1015:b008:a736:d5b4:4ac6:67ff:7e0b
# 92.23.238.244
# 219.91.139.113
# 2600:1015:b002:a523:3c53:26a8:5f86:2b5
# 2600:1015:b01b:2c95:a015:30ca:f3c:4c49
# 2600:1015:b023:55a7:b8e7:ebd5:d58f:7692
# 37.169.237.242
# 1.32.48.169
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Transcompiler&action=history
# 76.21.41.5
# 174.77.162.165
# 93.80.84.31
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Multi-paradigm_programming_language&action=history
# 75.139.254.117
# 98.197.198.46
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Object-oriented_programming&action=history
# 210.230.167.44
# 2a01:6500:a102:930b:50e1:a0:40e9:c9e7
# 144.138.25.66
# 2001:1970:5e63:e700:cb9:6b91:8e39:e3fc
# 2401:4900:110a:fe22:6c6a:dfb6:3848:df72
# 47.8.237.71
# 24.119.150.98
# 123.136.112.57
# 103.5.135.10
# 14.139.239.74
# 139.167.226.163
# 213.175.187.82
# 50.234.174.10
# 86.94.215.205
# 125.18.177.101
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Structured_programming&action=history
# 81.99.116.143
# 70.62.200.250
# 2407:7000:9301:da00:8da4:8cd:b7b6:e217
# 146.60.208.49
# 106.68.181.193
# 85.92.163.83
# 96.250.126.152
# 149.151.145.180
# 49.207.60.104
# 98.166.185.229
# 77.16.51.253
# 203.205.34.102
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Functional_programming&action=history
# 129.7.106.20
# 194.55.194.254
# 212.112.100.239
# 174.116.65.139
# 49.197.5.59
# 205.175.119.118
# 2405:205:24a7:f8d4:4a2c:f2a7:55e5:7d7d
# 140.177.205.223
# 144.51.242.26
# 90.95.200.195
# 193.57.249.5
# 210.212.209.66
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Aspect-oriented_programming&action=history
# 89.203.221.22
# 198.91.139.118
# 192.248.22.102
# 165.234.101.67
# 204.11.5.125
# 187.77.176.242
# 122.180.244.220
# 165.225.104.50
# 2600:1003:b107:caf6:f565:9bab:bc7e:c2af
# 192.252.75.2
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Metaprogramming&action=history
# 192.195.80.232
# 47.49.191.219
# 84.249.29.58
# 138.246.2.199
# 31.223.129.244
# 2601:541:4500:1760:218:8bff:fe74:fe4f
# 2804:431:d71d:43ed:986d:f711:6f3d:ec44
# 192.84.19.225
# 189.244.101.43
# 108.4.219.225
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Metaobject&action=history
# 184.151.179.119
# 174.116.65.139
# 99.235.132.95
# 184.151.190.247
# 79.155.214.16
# 184.151.178.67
# 184.151.178.54
# 99.236.6.160
# 184.151.178.210
# 207.164.79.24
# 70.80.103.76
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Design_by_contract&action=history
# 192.196.142.52
# 58.169.208.218
# 213.95.133.22
# 2405:204:6209:7317:b286:f083:8bad:b213
# 94.173.166.133
# 50.233.158.234
# 185.46.212.173
# 2602:301:778e:6630::40
# 77.56.53.183
# 219.89.14.209
# 178.74.62.15
# 71.135.5.88
# 213.208.173.32
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Logic_programming&action=history
# 89.41.8.139
# 116.50.153.50
# 174.56.96.141
# 185.27.105.81
# 73.71.155.150
# 74.215.39.197
# 61.247.33.92
# 164.39.128.208
# 83.87.235.197
# 154.76.87.247
# 2001:e68:542e:5326:b9ed:831a:482e:9501
# 123.243.195.235
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Dynamic_typing&action=history
# 62.23.212.160
# 131.111.8.99
# 128.250.6.134
# 195.149.37.65
# 172.194.101.14
# 192.102.214.6
# 24.217.36.41
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Reference_counting&action=history
# 2a02:c7d:694d:9000:a0e8:1731:8ed:1529
# 2600:1702:3ad1:6730:c121:feec:5693:47d9
# 187.2.83.22
# 88.159.79.148
# 2602:306:c540:2a40:38e9:6c49:6154:1556
# 203.81.72.44
# 185.69.244.31
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Memory_management&action=history
# 192.153.117.2
# 2409:4064:799:4333::26b8:60a1
# 81.134.55.93
# 212.79.110.126
# 2.28.242.213
# 95.218.251.224
# 2405:204:7308:40ca:275d:b604:8af7:d9e6
# 5.41.140.65
# 80.3.214.237
# 180.151.74.34
# 196.43.183.170
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Name_resolution_(programming_languages)&action=history
# 160.178.254.67
# 180.246.144.32
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Late_binding&action=history
# 47.9.207.70
# 77.56.53.183
# 217.151.150.75
# 67.215.87.16
# 96.2.206.100
# 192.189.129.17
# 78.52.191.253
# 2600:1700:9380:5170:ddcd:88e6:d547:1edf
# 178.39.228.89
# 2601:9:5d00:f39:1d64:50d3:97c6:e95d
# 131.228.210.27
# 197.47.66.239
# 169.149.129.206
# 24.47.139.204
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Functional_programming&action=history
# 129.7.106.20
# 194.55.194.254
# 212.112.100.239
# 174.116.65.139
# 49.197.5.59
# 205.175.119.118
# 2405:205:24a7:f8d4:4a2c:f2a7:55e5:7d7d
# 140.177.205.223
# 144.51.242.26
# 90.95.200.195
# 193.57.249.5
# 210.212.209.66
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Lisp_(programming_language)&action=history
# 106.77.83.232
# 106.206.19.113
# 117.55.242.131
# 208.87.72.29
# 89.25.210.104
# 2600:1015:b02e:f7:4a3:848d:381d:836d
# 87.123.11.209
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=List_comprehension&action=history
# 72.141.253.126
# 158.42.184.230
# 142.169.78.179
# 96.55.40.177
# 46.242.8.14
# 90.225.83.101
# 147.251.229.23
# 83.244.191.158
# 2003:41:e4a:5f7b:7d40:d749:c583:a0bb
# 104.172.229.116
# 80.2.151.245
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Associative_array&action=history
# 14.139.244.210
# 175.17.90.223
# 213.100.229.151
# 104.129.196.162
# 66.116.38.89
# 49.197.236.65
# 142.119.121.59
# 68.113.104.149
# 192.107.156.200
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Generator_(computer_programming)&action=history
# 200.42.206.187
# 122.172.249.38
# 109.133.93.237
# 96.244.71.155
# 2602:47:d40e:f400:d15b:3a61:9ecd:e07
# 49.248.149.107
# 79.180.215.213
# 89.177.142.61
# 15.203.233.84
# 190.122.97.218
# 206.252.208.94
# 2601:645:8302:5491:7458:5e3b:9324:9b7a
# 103.73.70.78
# 98.25.89.128
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Haskell_(programming_language)&action=history
# 75.172.200.54
# 2a00:79e0:15:14:8d71:619c:64f4:3e0e
# 121.218.241.43
# 129.170.30.229
# 2600:1015:b066:3c0f:2d02:7f67:7544:58be
# 2a0c:5bc0:40:2b01:add0:96f7:7649:521d
# 2405:204:c101:6240::812:d0b0
# 192.86.3.5
# 2600:1015:b012:8575:6456:4473:db9:fe49
# 2600:1015:b002:a523:3c53:26a8:5f86:2b5
# 209.194.92.138
# 82.159.74.199
# 2600:1015:b00d:d701:8cdd:b051:e6cc:208d
# 209.171.14.170
# 144.208.212.194
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Standard_ML&action=history
# 146.198.48.0
# 217.63.243.134
# 2001:1970:55e5:a700:e154:b00:5554:49de
# 49.147.21.128
# 195.99.89.184
# 2602:306:343b:b7f0:c140:901b:a43:c7a9
# 96.250.126.152
# 198.206.25.150
# 74.12.161.225
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Zen_of_Python&action=history
# 47.72.230.129
# 203.106.141.31
# 118.148.164.32
# 2601:646:4100:2aeb:9571:9a93:bae5:c3aa
# 162.93.65.2
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Aphorism&action=history
# 108.52.189.78
# 182.182.87.55
# 172.0.192.139
# 68.132.60.35
# 98.143.74.220
# 62.74.17.6
# 31.53.36.58
# 49.248.118.74
# 204.4.13.72
# 49.229.173.250
# 200.158.28.112
# 37.46.182.125
# 122.11.137.90
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Extensibility&action=history
# 160.177.211.187
# 106.51.250.126
# 182.232.83.204
# 86.30.233.252
# 192.223.243.5
# 182.77.38.6
# 86.5.64.124
# 117.195.54.242
# 70.182.168.131
# 72.177.50.43
# 50.233.46.202
# 41.238.30.153
# 122.177.99.145
# 182.76.166.90
# 46.186.38.202
# 202.28.154.126
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=ABC_(programming_language)&action=history
# 67.183.15.243
# 24.218.155.160
# 117.195.212.149
# 72.188.68.228
# 113.162.145.67
# 24.106.95.243
# 24.91.6.95
# 14.1.193.137
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Perl&action=history
# 124.149.241.66
# 2600:1:c615:e9f4:510d:8aee:5b14:8c90
# 93.185.27.86
# 69.203.220.223
# 2001:1970:4fa1:af00:25ee:4cb3:40c4:6765
# 49.248.128.16
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Alex_Martelli&action=history
# 65.25.243.236
# 189.4.241.31
# 118.83.129.139
# 68.39.100.192
# 24.130.18.117
# 195.84.108.153
# 75.119.248.135
# 99.104.125.62
# 80.178.10.226
# 108.80.56.233
# 162.39.180.2
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=There_is_more_than_one_way_to_do_it&action=history
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Premature_optimization&action=history
# 207.135.14.156
# 200.84.178.233
# 24.57.176.176
# 216.170.164.248
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=CPython&action=history
# 80.94.115.69
# 194.7.161.147
# 37.209.27.56
# 2405:204:72c1:1dd5:9e32:9f48:e259:438d
# 107.222.53.148
# 86.111.159.216
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=PyPy&action=history
# 205.175.106.25
# 62.172.100.253
# 5.151.0.120
# 86.23.54.173
# 180.66.165.186
# 67.168.214.174
# 86.179.22.30
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Just-in-time_compilation&action=history
# 2402:1980:8250:e532:f8c9:b6da:c251:9bec
# 129.7.0.122
# 190.195.179.29
# 109.80.199.152
# 2405:204:d18a:fc63:e86f:e864:4903:7bd1
# 144.82.180.19
# 147.188.254.192
# 105.112.22.124
# 24.190.24.112
# 64.134.165.136
# 99.203.10.179
# 143.59.78.3
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Cython&action=history
# 185.193.199.213
# 2600:6c58:627f:e8ca:81c8:2af8:becd:f3d4
# 79.13.132.173
# 70.36.145.190
# 148.88.152.95
# 88.111.109.115
# 84.224.142.98
# 70.184.214.35
# 179.50.208.75
# 212.216.239.205
# 173.230.196.25
# 160.3.49.37
# 173.228.46.185
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Monty_Python&action=history
# 168.120.65.41
# 86.2.65.41
# 51.37.192.126
# 115.189.85.73
# 2806:262:40b:9d2:816f:7282:ae5b:9c97
# 147.85.172.6
# 61.47.243.47
# 86.149.213.123
# 65.117.99.172
# 69.181.28.115
# 2601:541:4500:1760:98d9:2d81:cf6f:325e
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Spam_(Monty_Python)&action=history
# 2601:600:8180:7ae:5db2:b1a4:9321:392b
# 149.62.200.197
# 69.158.44.108
# 2601:600:8180:7ae:6933:cc3c:50f9:8b2f
# 64.175.40.229
# 24.131.62.102
# 86.17.116.223
# 192.252.228.117
# 2605:e000:c9c0:c00:28e0:8e2b:890d:5ca0
# 120.56.173.104
# 2800:a4:1060:3e00:211d:49a6:cf77:3fdc
# 2600:1700:f1c0:7610:e906:19a1:854b:1e30
# 108.0.187.11
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Foobar&action=history
# 24.97.229.35
# 2601:602:ce00:10a0:69ad:7b72:e4aa:833b
# 2a02:8071:31a7:9700:be5f:f4ff:fee0:4b1b
# 2a02:2f0d:fff:ffff::50e:20b5
# 203.189.181.135
# 73.56.213.132
# 2605:6000:8b8f:e300:6c26:1b1a:e609:ef32
# 82.16.20.21
# 2001:d08:dd:cbf5:254e:bf57:5548:2a4b
# 216.248.238.46
# 104.39.153.78
# 169.232.246.182
# 170.251.61.67
# 183.15.177.169
# 154.5.169.5
# 82.132.239.134
# 5.134.130.192
# 185.65.55.2
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Neologism&action=history
# 108.35.213.214
# 209.237.102.98
# 24.38.10.6
# 1.132.106.39
# 129.7.104.28
# 178.152.69.136
# 211.217.110.151
# 211.27.71.53
# 76.67.59.40
# 71.7.161.226
# 73.80.117.120
# 79.69.66.124
# 109.224.219.228
# 92.13.138.154
# 2610:148:1f00:0:4070:b23a:8ac:9ea4
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Python_syntax_and_semantics&action=history
# 175.157.216.188
# 24.136.125.188
# 119.93.154.241
# 131.94.186.13
# 213.168.107.162
# 206.47.13.59
# 70.82.10.225
# 99.245.81.86
# 2a02:c7d:ce08:c800:c5e4:f78c:b21f:8f6d
# 85.240.211.87
# 193.240.177.234
# 2a02:c7d:694d:9000:c218:85ff:fe87:2d93
# 213.87.144.54
# 36.22.60.60
# 24.155.167.224
# 192.241.63.79
# 177.96.253.209
# 108.27.68.139
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Curly_bracket_programming_language&action=history
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-39231a97fa80> in <module>
#      34     for link in links:
#      35         print('-'*20)
# ---> 36         historyIPs = getHistoryIPs(link.attrs['href'])
#      37         for historyIP in historyIPs:
#      38             print(historyIP)
#
# <ipython-input-2-39231a97fa80> in getHistoryIPs(pageUrl)
#      19     historyUrl = 'http://en.wikipedia.org/w/index.php?title={}&action=history'.format(pageUrl)
#      20     print('history url is: {}'.format(historyUrl))
# ---> 21     html = urlopen(historyUrl)
#      22     bs = BeautifulSoup(html, 'html.parser')
#      23     #finds only the links with class "mw-anonuserlink" which has IP addresses
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1315             try:
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1273             # default charset of iso-8859-1.
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#    1277     def getresponse(self):
#
# ~\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1222         else:
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#    1226     def request(self, method, url, body=None, headers={}, *,
#
# ~\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1014         msg = b"\r\n".join(self._buffer)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#    1018         if message_body is not None:
#
# ~\Anaconda3\lib\http\client.py in send(self, data)
#     954         if self.sock is None:
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#     958                 raise NotConnected()
#
# ~\Anaconda3\lib\http\client.py in connect(self)
#    1382             "Connect to a host on a given (SSL) port."
#    1383
# -> 1384             super().connect()
#    1385
#    1386             if self._tunnel_host:
#
# ~\Anaconda3\lib\http\client.py in connect(self)
#     926         """Connect to the host and port specified in __init__."""
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     930
#
# ~\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# KeyboardInterrupt:

# %%
def getCountry(ipAddress):
    try:
        response = urlopen(
            'http://freegeoip.net/json/{}'.format(ipAddress)).read().decode('utf-8')
    except HTTPError:
        return None
    responseJson = json.loads(response)
    return responseJson.get('country_code')
    
links = getLinks('/wiki/Python_(programming_language)')

while(len(links) > 0):
    for link in links:
        print('-'*20) 
        historyIPs = getHistoryIPs(link.attrs["href"])
        for historyIP in historyIPs:
            country = getCountry(historyIP)
            if country is not None:
                print('{} is from {}'.format(historyIP, country))

    newLink = links[random.randint(0, len(links)-1)].attrs['href']
    links = getLinks(newLink)
# Out:
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Programming_paradigm&action=history
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-4f510a55b514> in getCountry(ipAddress)
#       3         response = urlopen(
# ----> 4             'http://freegeoip.net/json/{}'.format(ipAddress)).read().decode('utf-8')
#       5     except HTTPError:
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 403: Forbidden
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4f510a55b514> in <module>
#      15         historyIPs = getHistoryIPs(link.attrs["href"])
#      16         for historyIP in historyIPs:
# ---> 17             country = getCountry(historyIP)
#      18             if country is not None:
#      19                 print('{} is from {}'.format(historyIP, country))
#
# <ipython-input-3-4f510a55b514> in getCountry(ipAddress)
#       3         response = urlopen(
#       4             'http://freegeoip.net/json/{}'.format(ipAddress)).read().decode('utf-8')
# ----> 5     except HTTPError:
#       6         return None
#       7     responseJson = json.loads(response)
#
# NameError: name 'HTTPError' is not defined
